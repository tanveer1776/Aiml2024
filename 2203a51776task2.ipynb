# %%
import pandas as pd
people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]
healthcare_data = pd.DataFrame({
    'Name': people,
        'Age': age,
            'Height': height,
                'Weight': weight
                })
print(healthcare_data)
# Out:
#     Name  Age  Height  Weight
# 0  kiran   25     145      45
# 1   arun   30     151      55
# 2  vijay   35     165      65
# 3  varun   40     173      75

# %%
import matplotlib.pyplot as plt
plt.scatter(healthcare_data['Age'], healthcare_data['Weight'])
plt.title('Scatter Plot of Age vs Weight in Healthcare Data')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(healthcare_data['Name'], healthcare_data['Height'], color='purple')
# Graph Title and Labels
plt.title('Bar Chart of Height for Individuals in Healthcare Data')
plt.xlabel('Name')
plt.ylabel('Height')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(healthcare_data['Age'])
plt.title('Histogram of Age in Healthcare Data')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
